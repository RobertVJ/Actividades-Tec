# %%
"""
Momento de Retroalimentación: Módulo 3 NLP Module Project.
(Implemantation Portafolio )

Fecha Inicio del Trabajo:  27/08/2022

Fecha de Finalizado: 11/11/2022


Nombre: Roberto Valdez

Matricula: A01746863


Introductions:

This homework is designed to give you a glimpse of 
what it’s like to be an NLP-focused software developer 
in industry.  All of these are realistic tasks, 
loosely based upon work I have done for real companies! 


Please write your own code. I will read all code,
and if two students’ code is suspiciously similar 
(i.e. obviously copied from another),
it will result in a 0 score for all involved parties. 
It is okay to discuss the project and approaches at a 
high level with your classmates, but it is not okay 
to copy-paste code from a friend.

Evaluation Metrics link: 
https://experiencia21.tec.mx/courses/315342/assignments/9856676


Tasks: 

3. Set up and compare model performance of two different translation models
  * Imagine you’re a developer now, and your boss wants you to add a little translation module. This would be the first step in choosing what API you are going to use!
  * You are not training a model, you are simply calling and comparing the results of different APIs.
  * Use the first 100 lines from the Spanish-English dataset here: 
https://www.statmt.org/europarl/Enlaces
  * You can choose any two models that you find online. Amazon, Google, IBM etc, as well as many other smaller companies, all have models – pick two that you find interesting.
  * WHAT TO PRINT: 
    * For each of the models, the name of the model, and the average BLEU score. over those 100 examples
    * Example:   

    
AMAZON_TRANSLATOR: 0.2

GOOGLE_TRANSLATOR: 0.3
 
"""
# Out:
# '\nMomento de Retroalimentación: Módulo 3 NLP Module Project.\n(Implemantation Portafolio )\n\nFecha Inicio del Trabajo:  27/08/2022\n\nFecha de Finalizado: 11/11/2022\n\n\nNombre: Roberto Valdez\n\nMatricula: A01746863\n\n\nIntroductions:\n\nThis homework is designed to give you a glimpse of \nwhat it’s like to be an NLP-focused software developer \nin industry.  All of these are realistic tasks, \nloosely based upon work I have done for real companies! \n\n\nPlease write your own code. I will read all code,\nand if two students’ code is suspiciously similar \n(i.e. obviously copied from another),\nit will result in a 0 score for all involved parties. \nIt is okay to discuss the project and approaches at a \nhigh level with your classmates, but it is not okay \nto copy-paste code from a friend.\n\nEvaluation Metrics link: \nhttps://experiencia21.tec.mx/courses/315342/assignments/9856676\n\n\nTasks: \n\n3. Set up and compare model performance of two different translation models\n  * Imagine you’re a developer now, and your boss wants you to add a little translation module. This would be the first step in choosing what API you are going to use!\n  * You are not training a model, you are simply calling and comparing the results of different APIs.\n  * Use the first 100 lines from the Spanish-English dataset here: \nhttps://www.statmt.org/europarl/Enlaces\n  * You can choose any two models that you find online. Amazon, Google, IBM etc, as well as many other smaller companies, all have models – pick two that you find interesting.\n  * WHAT TO PRINT: \n    * For each of the models, the name of the model, and the average BLEU score. over those 100 examples\n    * Example:   \n\n    \nAMAZON_TRANSLATOR: 0.2\n\nGOOGLE_TRANSLATOR: 0.3\n \n'

# %%
# download command for googletrans translator library with pip
# !pip install googletrans==3.1.0a0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 683 kB/s
# Collecting hstspreload
#   Downloading hstspreload-2022.11.1-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 9.4 MB/s
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 502 kB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2022.9.24)
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 244 kB/s
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 965 kB/s
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16368 sha256=cc1d08013c52dd1d1b3d7197a12b49eb102b4744d7a621ae1f79e77c00c2d1fd
#   Stored in directory: /root/.cache/pip/wheels/0c/be/fe/93a6a40ffe386e16089e44dad9018ebab9dc4cb9eb7eab65ae
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, sniffio, h2, h11, rfc3986, httpcore, hstspreload, httpx, googletrans
# Successfully installed googletrans-3.1.0a0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2022.11.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 rfc3986-1.5.0 sniffio-1.3.0

# %%
pip install translate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting translate
#   Downloading translate-3.6.1-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from translate) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from translate) (4.9.1)
# Collecting libretranslatepy==2.1.1
#   Downloading libretranslatepy-2.1.1-py3-none-any.whl (3.2 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from translate) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->translate) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->translate) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->translate) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->translate) (2022.9.24)
# Installing collected packages: libretranslatepy, translate
# Successfully installed libretranslatepy-2.1.1 translate-3.6.1

# %%
# Libraries for this Activity
import googletrans 
from nltk.translate.bleu_score import sentence_bleu
import pandas as pd
import translate

# %%
# Class NLPActivity_3
class nlpactivity3:
  # _init_ method
  def __init__(self, testfile, originalfile):
     self.testfile = testfile 
     self.originalfile =  originalfile


  # google_Traductor_acc method
  """
  This method helps us to open and read the document,
  translate with google traductor of the selected document
  and generate a numerical precision according to the
  certainty score that said translation of the original document contains.
  """
  def google_traductor_acc(testfile, originalfile):
    # Calling the google translator function

    translator = googletrans.Translator()

    # opening, reanding and translating  the document, line by line
    with open(testfile, 'r') as tf:
      x = tf.readlines()[0:100]
      i= 0
      for i in range(100):
        translated = translator.translate(x[i], src='en', dest='es')

    # Selecting 100 lines of the original file for testing the translator method
    with open(originalfile, 'r') as tf:
        y = tf.readlines()[0:100]
        i = 0

    i = 0
    for i in range(100): 
      ref = y[i].split() 
      test01 = x[i].split()
      i += 1
      print('GOOGLE TRANSLATOR: {}'.format(sentence_bleu(ref, test01))) # testing acc

  def google_traductor(testfile, originalfile):
    translator = googletrans.Translator()

    with open(testfile, 'r') as tf:
      x = tf.readlines()[0:100]
      i= 0
      for i in range(100):
        translated = translator.translate(x[i], src='en', dest='es')
        i += 1
        print(translated.text) # pritting the text translated

  # simple_Traductor_Acc method
  """
  This method helps us to open and read the document,
  translate with the simple traductor library of the selected document
  and generate a numerical precision according to the
  certainty score that said translation of the original document contains.
  """
  def simple_traductor_acc(testfile, originalfile):
    # Calling the simple translator function

    translator = translate.Translator(from_lang="english",to_lang="spanish")

    # opening, reanding and translating  the document, line by line
    with open(testfile, 'r') as tf:
      x = tf.readlines()[0:100]
      i= 0
      for i in range(100):
        translated = translator.translate(x[i])

    # Selecting 100 lines of the original file for testing the translator method
    with open(originalfile, 'r') as tf:
        y = tf.readlines()[0:100]
        i = 0
 
    i = 0
    for i in range(100): 
      ref = y[i].split() 
      test01 = x[i].split()
      i += 1
      print('Simple TRANSLATOR: {}'.format(sentence_bleu(ref, test01))) # testing acc

  def simple_traductor(testfile, originalfile):
    translator = translate.Translator(from_lang="english",to_lang="spanish")

    with open(testfile, 'r') as tf:
      x = tf.readlines()[0:100]
      i= 0
      for i in range(100):
        translated = translator.translate(x[i]) 
        i += 1
        print(translated) # pritting the text translated

# %%
# We call the class and perform the test with the google translator
googleTrad = nlpactivity3.google_traductor_acc("./europarl-v7.es-en.en.txt", "./europarl-v7.es-en.es.txt")
# Out:
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 8.726094729337945e-232
# GOOGLE TRANSLATOR: 9.181748633447778e-232
# GOOGLE TRANSLATOR: 8.726094729337945e-232
# GOOGLE TRANSLATOR: 9.533966891110756e-232
# GOOGLE TRANSLATOR: 1.0832677820940877e-231
# GOOGLE TRANSLATOR: 1.2508498911928379e-231
# GOOGLE TRANSLATOR: 1.1200407237786664e-231
# GOOGLE TRANSLATOR: 8.319100378795605e-232
# GOOGLE TRANSLATOR: 8.147480343967206e-232
# GOOGLE TRANSLATOR: 8.18873472774142e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 1.1200407237786664e-231
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 9.594503055152632e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 9.418382295637229e-232
# GOOGLE TRANSLATOR: 8.972141065609098e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 9.157231061812019e-232
# GOOGLE TRANSLATOR: 7.784451369270533e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 8.510469113101058e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 7.919883909890055e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 6.630398171726777e-232
# GOOGLE TRANSLATOR: 6.720628411503338e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 8.972141065609098e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 1.0244914152188952e-231
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 8.147480343967206e-232
# GOOGLE TRANSLATOR: 8.412065649527267e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 7.919883909890055e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 8.06798322521923e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 9.257324954728539e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 9.594503055152632e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 7.659859945595747e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 7.919883909890055e-232
# GOOGLE TRANSLATOR: 9.788429383461836e-232
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 8.231055179516831e-232
# GOOGLE TRANSLATOR: 9.788429383461836e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 8.048704752395483e-232
# GOOGLE TRANSLATOR: 7.720899511627474e-232
# GOOGLE TRANSLATOR: 7.640041254455826e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 8.477028509227734e-232
# GOOGLE TRANSLATOR: 8.06798322521923e-232
# GOOGLE TRANSLATOR: 6.752107625974243e-232
# GOOGLE TRANSLATOR: 6.492476721861418e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 8.726094729337945e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 9.109159947227211e-232
# GOOGLE TRANSLATOR: 9.788429383461836e-232
# GOOGLE TRANSLATOR: 0
# GOOGLE TRANSLATOR: 7.601159375410181e-232
# GOOGLE TRANSLATOR: 1.0003688322288243e-231

# %%
# We call the class and perform the test with the simple translator library
simpleTrad = nlpactivity3.simple_traductor_acc("./europarl-v7.es-en.en.txt", "./europarl-v7.es-en.es.txt")
# Out:
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 8.726094729337945e-232
# Simple TRANSLATOR: 9.181748633447778e-232
# Simple TRANSLATOR: 8.726094729337945e-232
# Simple TRANSLATOR: 9.533966891110756e-232
# Simple TRANSLATOR: 1.0832677820940877e-231
# Simple TRANSLATOR: 1.2508498911928379e-231
# Simple TRANSLATOR: 1.1200407237786664e-231
# Simple TRANSLATOR: 8.319100378795605e-232
# Simple TRANSLATOR: 8.147480343967206e-232
# Simple TRANSLATOR: 8.18873472774142e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 1.1200407237786664e-231
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 9.594503055152632e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 9.418382295637229e-232
# Simple TRANSLATOR: 8.972141065609098e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 9.157231061812019e-232
# Simple TRANSLATOR: 7.784451369270533e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 8.510469113101058e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 7.919883909890055e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 6.630398171726777e-232
# Simple TRANSLATOR: 6.720628411503338e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 8.972141065609098e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 1.0244914152188952e-231
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 8.147480343967206e-232
# Simple TRANSLATOR: 8.412065649527267e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 7.919883909890055e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 8.06798322521923e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 9.257324954728539e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 9.594503055152632e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 7.659859945595747e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 7.919883909890055e-232
# Simple TRANSLATOR: 9.788429383461836e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 8.231055179516831e-232
# Simple TRANSLATOR: 9.788429383461836e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 8.048704752395483e-232
# Simple TRANSLATOR: 7.720899511627474e-232
# Simple TRANSLATOR: 7.640041254455826e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 8.477028509227734e-232
# Simple TRANSLATOR: 8.06798322521923e-232
# Simple TRANSLATOR: 6.752107625974243e-232
# Simple TRANSLATOR: 6.492476721861418e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 8.726094729337945e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 9.109159947227211e-232
# Simple TRANSLATOR: 9.788429383461836e-232
# Simple TRANSLATOR: 0
# Simple TRANSLATOR: 7.601159375410181e-232
# Simple TRANSLATOR: 1.0003688322288243e-231

# %%
"""
As seen in the tests carried out previously, we can denote that 
the translations were accurate at the time of exchanging the text 
from one language to another, now, according to their scores they 
were really accurate, but to see that the translation was really 
done translation, we call the following functions
"""
# Out:
# '\nAs seen in the tests carried out previously, we can denote that \nthe translations were accurate at the time of exchanging the text \nfrom one language to another, now, according to their scores they \nwere really accurate, but to see that the translation was really \ndone translation, we call the following functions\n'

# %%
# testing the Google Translator process
tradGoogle = nlpactivity3.google_traductor("./europarl-v7.es-en.en.txt", "./europarl-v7.es-en.es.txt")
# Out:
# Reanudación de la sesión
# Declaro reanudado el período de sesiones del Parlamento Europeo interrumpido el viernes 17 de diciembre de 1999, y me gustaría desearles una vez más un feliz año nuevo esperando que hayan disfrutado de un agradable período festivo.
# Aunque, como habrán visto, el temido 'error del milenio' no se materializó, la gente de varios países sufrió una serie de desastres naturales que fueron realmente terribles.
# Usted ha solicitado un debate sobre este tema en el transcurso de los próximos días, durante este período parcial de sesiones.
# Mientras tanto, me gustaría guardar un minuto de silencio, como han pedido varios diputados, en nombre de todas las víctimas afectadas, en particular las de las terribles tormentas, en los distintos países de la Unión Europea.
# Por favor, levántense, entonces, para este minuto de silencio.
# (La Cámara se levanta y guarda un minuto de silencio)
# Señora Presidenta, sobre una cuestión de orden.
# Usted sabrá por la prensa y la televisión que ha habido una serie de explosiones de bombas y asesinatos en Sri Lanka.
# Una de las personas asesinadas recientemente en Sri Lanka fue el Sr. Kumar Ponnambalam, quien había visitado el Parlamento Europeo hace apenas unos meses.
# Señora Presidenta, ¿sería apropiado que escribiera una carta a la Presidenta de Sri Lanka expresando el pesar del Parlamento por su muerte y las demás muertes violentas en Sri Lanka e instándola a hacer todo lo posible para buscar una reconciliación pacífica en un momento muy difícil? ¿situación?
# Sí, señor Evans, creo que una iniciativa del tipo que acaba de sugerir sería totalmente apropiada.
# Si la Cámara está de acuerdo, haré lo que ha sugerido el Sr. Evans.
# Señora Presidenta, sobre una cuestión de orden.
# Quisiera su consejo sobre la regla 143 relativa a la inadmisibilidad.
# Mi pregunta se relaciona con algo que surgirá el jueves y que luego volveré a plantear.
# El informe Cunha sobre los programas de orientación plurianuales se presenta ante el Parlamento el jueves y contiene una propuesta en el párrafo 6 de que se debe introducir una forma de sanciones de cuota para los países que no cumplan con sus objetivos de reducción de la flota anualmente.
# Dice que esto debe hacerse a pesar del principio de estabilidad relativa.
# Creo que el principio de estabilidad relativa es un principio jurídico fundamental de la política pesquera común y una propuesta para subvertirlo sería legalmente inadmisible.
# Quiero saber si se puede plantear una objeción de ese tipo a lo que es simplemente un informe, no una propuesta legislativa, y si eso es algo que puedo hacer de manera competente el jueves.
# Ese es precisamente el momento en que usted puede, si lo desea, plantear esta pregunta, es decir, el jueves anterior al inicio de la presentación del informe.
# Señora Presidenta, coincidiendo con el primer período parcial de sesiones del Parlamento Europeo de este año, se ha fijado una fecha, lamentablemente para el próximo jueves, en Texas, Estados Unidos, para la ejecución de un joven de 34 años que ha sido condenado a muerte. Lo llamaremos Sr. Hicks.
# A petición de un diputado francés, el señor Zimeray, ya se ha presentado una petición que firmaron muchas personas, incluido yo mismo. Sin embargo, le pediría, de acuerdo con la línea que ahora sigue constantemente el Parlamento Europeo y el conjunto de la Comunidad Europea, que haga gestiones, utilizando el peso de su prestigioso cargo y de la institución que representa, al Presidente y al Gobernador de Texas, Sr. Bush, quien tiene el poder de ordenar una suspensión de la ejecución y de indultar a la persona condenada.
# Todo ello de acuerdo con los principios que siempre hemos defendido.
# Gracias, señor Segni, lo haré con mucho gusto.
# De hecho, está muy en consonancia con las posiciones que siempre ha adoptado esta Cámara.
# Señora Presidenta, me gustaría llamar su atención sobre un caso en el que este Parlamento ha mostrado constantemente interés.
# Es el caso de Alexander Nikitin.
# Todos los que estamos aquí estamos complacidos de que los tribunales lo hayan absuelto y hayan dejado en claro que en Rusia, también, el acceso a la información ambiental es un derecho constitucional.
# Ahora, sin embargo, debe acudir nuevamente a los tribunales porque el fiscal está apelando.
# Sabemos, y así lo hemos afirmado en muchas resoluciones, incluso específicamente durante la última sesión plenaria del año pasado, que no se trata únicamente de un caso legal y que está mal que se acuse a Alexander Nikitin de actividad delictiva y traición debido a nuestra participación como beneficiarios de sus hallazgos.
# Estos hallazgos forman la base de los programas europeos para proteger el Mar de Barents, y por eso les pido que examinen un proyecto de carta en el que se expongan los hechos más importantes y que hagan que la posición del Parlamento, tal como se expresa en las resoluciones que ha adoptado, claro en lo que respecta a Rusia.
# Sí, señora Schroedter, estaré encantado de investigar los hechos de este caso cuando haya recibido su carta.
# Señora Presidenta, en primer lugar me gustaría felicitarla por el hecho de que ha cumplido su palabra y que, durante este primer período parcial de sesiones del nuevo año, el número de canales de televisión en nuestras oficinas ha aumentado considerablemente.
# Pero señora Presidenta, mi petición personal no ha sido atendida.
# Aunque ahora hay dos canales finlandeses y uno portugués, todavía no hay un canal holandés, que es lo que había solicitado porque a los holandeses aquí también les gusta poder seguir las noticias cuando nos envían a este lugar de exilio todos los meses.
# Por lo tanto, le pido una vez más que se asegure de que también tengamos un canal holandés.
# Señora Plooij-van Gorsel, puedo decirle que este asunto está en el orden del día de la reunión de los Cuestores del miércoles.
# Espero que sea examinado bajo una luz positiva.
# Señora Presidenta, ¿puede decirme por qué este Parlamento no se adhiere a la legislación sobre salud y seguridad que realmente aprueba?
# ¿Por qué no se ha realizado ninguna prueba de calidad del aire en este edificio en particular desde que fuimos elegidos?
# ¿Por qué no ha habido una reunión del Comité de Seguridad y Salud desde 1998?
# ¿Por qué no ha habido ningún simulacro de incendio, ni en los edificios del Parlamento de Bruselas ni en los edificios del Parlamento de Estrasburgo?
# ¿Por qué no hay instrucciones de incendio?
# ¿Por qué no se han mejorado las escaleras desde mi accidente?
# ¿Por qué no se aplican las áreas de no fumar?
# Propongo que votemos sobre la solicitud del Grupo del Partido de los Socialistas Europeos de que se restablezca la declaración de la Comisión sobre sus objetivos estratégicos.
# (El Parlamento rechaza la solicitud) Presidente.
# Todavía en el tema de la sesión del miércoles, tengo otra propuesta con respecto a la pregunta oral sobre el impuesto al capital.
# El Grupo del PPE-DE solicita que se retire este punto del orden del día.
# ¿Hay algún miembro que desee hablar en nombre de este Grupo para proponer esto?
# Señora Presidenta, puedo oír una oleada de risas de los socialistas.
# Me dijeron que amplios sectores del Grupo Socialista también estaban interesados ​​en que se quitara este punto del orden del día, porque en la votación en la Conferencia de Presidentes no se recibió ningún voto del grupo de trabajo de diputados del Grupo Socialista responsable de este asunto.
# No sé si esta información es correcta, pero el Grupo del PPE-DE, en cualquier caso, agradecería que se suprimiera este punto porque el Parlamento ya ha abordado este tema varias veces.
# También se han adoptado decisiones en contra de un impuesto de este tipo.

# %%
# testing the simple Translator process
# it's a bit slow but it gets the job done
"""
On the other hand, with this library we are using the free translation package, 
which imposes a limit on the number of translations per day which is 
"recharged" once a certain amount of time has passed.
"""
tradGoogle = nlpactivity3.simple_traductor("./europarl-v7.es-en.en.txt", "./europarl-v7.es-en.es.txt")
# Out:
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 05 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 04 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 04 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 04 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 04 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 03 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 03 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 03 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 03 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 02 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 02 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 02 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 02 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 01 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 01 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 01 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 01 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 01 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 00 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 00 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 00 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  10 HOURS 44 MINUTES 00 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-8f2f28c0da45> in <module>
#       6 "recharged" once a certain amount of time has passed.
#       7 """
# ----> 8 tradGoogle = nlpactivity3.simple_traductor("./europarl-v7.es-en.en.txt", "./europarl-v7.es-en.es.txt")
#
# <ipython-input-7-84a03e23fc9e> in simple_traductor(testfile, originalfile)
#      87       i= 0
#      88       for i in range(100):
# ---> 89         translated = translator.translate(x[i])
#      90         i += 1
#      91         print(translated) # pritting the text translated
#
# /usr/local/lib/python3.7/dist-packages/translate/translate.py in translate(self, text)
#      43
#      44         text_list = wrap(text, TRANSLATION_API_MAX_LENGHT, replace_whitespace=False)
# ---> 45         return ' '.join(self.provider.get_translation(text_wraped) for text_wraped in text_list)
#
# /usr/local/lib/python3.7/dist-packages/translate/translate.py in <genexpr>(.0)
#      43
#      44         text_list = wrap(text, TRANSLATION_API_MAX_LENGHT, replace_whitespace=False)
# ---> 45         return ' '.join(self.provider.get_translation(text_wraped) for text_wraped in text_list)
#
# /usr/local/lib/python3.7/dist-packages/translate/providers/mymemory_translated.py in get_translation(self, text)
#      40
#      41     def get_translation(self, text):
# ---> 42         data = self._make_request(text)
#      43
#      44         translation = data['responseData']['translatedText']
#
# /usr/local/lib/python3.7/dist-packages/translate/providers/mymemory_translated.py in _make_request(self, text)
#      36             params['de'] = self.email
#      37
# ---> 38         response = requests.get(self.base_url, params=params, headers=self.headers)
#      39         return response.json()
#      40
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# /usr/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
"""
Once the translations are finished and reviewing the 
prediction and precision of said translations,
we can denote that these libraries are very precise, 
giving the expected results for this activity.
"""
